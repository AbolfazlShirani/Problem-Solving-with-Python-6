# %%
def  sequence(n):
    if(n==0):
        return 1
    return  sequence(n-1)*2

sequence(8)
# Out:
# 256

# %%
def sequenses(n):
    if(n==0):
        return 1
    return n*sequenses(n-1)

sequenses(5)
# Out:
# 120
